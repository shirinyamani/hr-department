# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./data/data.csv')

# %%
df.head(5)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
# extract only the int64 dtype
int64_dtypes = df.dtypes[df.dtypes =='int64'].index.to_list()

# %%
len(int64_dtypes)
# Out:
# 26

# %%
#mean of the age
df['Age'].mean()
# Out:
# 36.923809523809524

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
#replace the Yes/No in attritittion, overtime, over18 colums
mapping = {'Yes':1, 'Y':1, 'No':0, 'N':0}
df = df.applymap(lambda x:mapping.get(x,x))

#same as if you want to do it manually for each of the cols
df['Over18']=df['Over18'].apply(lambda x: 1 if x=='Yes' or 'Y' else 0)

# %%
#check for null values
df.isnull().sum()
df.isna().any().any()
# Out:
# False

# %%
#count the number of the 1s in the colums
(df['EmployeeCount']== 1).sum() #col wise
df[df['Attrition']==1].shape[0] #row wise
set(df['Education']) #see different values
# Out:
# {1, 2, 3, 4, 5}

# %%
#remove the non-informative cols
df.drop(['EmployeeCount', 'StandardHours', 'Over18', 'EmployeeNumber'], axis=1, inplace=True)

# %%
df.shape #as we drop 4 non-uselful cols
# Out:
# (1470, 31)

# %%
#see the ppl who left the company
left_df = df[df['Attrition'] == 1]
stayed_df = df[df['Attrition'] == 0]

# %%
print(f'left ppl:{len(left_df)}, stayed ppl:{len(stayed_df)}')
# Out:
# left ppl:237, stayed ppl:1233

# %%
left_df.describe()
# Out:
#               Age  Attrition    DailyRate  DistanceFromHome   Education  \
# count  237.000000      237.0   237.000000        237.000000  237.000000
# mean    33.607595        1.0   750.362869         10.632911    2.839662
# std      9.689350        0.0   401.899519          8.452525    1.008244
# min     18.000000        1.0   103.000000          1.000000    1.000000
# 25%     28.000000        1.0   408.000000          3.000000    2.000000
# 50%     32.000000        1.0   699.000000          9.000000    3.000000
# 75%     39.000000        1.0  1092.000000         17.000000    4.000000
# max     58.000000        1.0  1496.000000         29.000000    5.000000
#
#        EnvironmentSatisfaction  HourlyRate  JobInvolvement    JobLevel  \
# count               237.000000  237.000000      237.000000  237.000000
# mean                  2.464135   65.573840        2.518987    1.637131
# std                   1.169791   20.099958        0.773405    0.940594
# ...

# %%
stayed_df.describe()
# Out:
#                Age  Attrition    DailyRate  DistanceFromHome    Education  \
# count  1233.000000     1233.0  1233.000000       1233.000000  1233.000000
# mean     37.561233        0.0   812.504461          8.915653     2.927007
# std       8.888360        0.0   403.208379          8.012633     1.027002
# min      18.000000        0.0   102.000000          1.000000     1.000000
# 25%      31.000000        0.0   477.000000          2.000000     2.000000
# 50%      36.000000        0.0   817.000000          7.000000     3.000000
# 75%      43.000000        0.0  1176.000000         13.000000     4.000000
# max      60.000000        0.0  1499.000000         29.000000     5.000000
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              1233.000000  1233.000000     1233.000000  1233.000000
# mean                  2.771290    65.952149        2.770479     2.145985
# std                   1.071132    20.380754        0.692050     1.117933
# ...

# %%
plt.figure(figsize=[25, 12])
sns.countplot(x = 'Age', hue = 'Attrition', data = df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
plt.figure(figsize=(12,7))

sns.kdeplot(left_df['DistanceFromHome'], label = 'Employees who left', shade = True, color = 'r')
sns.kdeplot(stayed_df['DistanceFromHome'], label = 'Employees who Stayed', shade = True, color = 'b')

plt.xlabel('Distance From Home')
# Out:
# /tmp/ipykernel_73665/1980401044.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(left_df['DistanceFromHome'], label = 'Employees who left', shade = True, color = 'r')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[105], line 3
#       1 plt.figure(figsize=(12,7))
# ----> 3 sns.kdeplot(left_df['DistanceFromHome'], label = 'Employees who left', shade = True, color = 'r')
#       4 sns.kdeplot(stayed_df['DistanceFromHome'], label = 'Employees who Stayed', shade = True, color = 'b')
#       6 plt.xlabel('Distance From Home')
#
# ...
